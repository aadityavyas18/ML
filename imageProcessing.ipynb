# %%
import cv2
import skimage as ski
import matplotlib.pyplot as plt

# %%
img=cv2.imread('OIP.jpg')

# %%
img
# Out:
# array([[[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        ...,
#
#        [[ 20,  32,  90],
#         [  6,  19,  75],
#         [  8,  20,  74],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[ 32,  45, 101],
#         [ 15,  27,  81],
#         [ 13,  24,  76],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[ 48,  60, 114],
#         [ 23,  36,  88],
#         [ 15,  26,  76],
# ...

# %%
img.shape
# Out:
# (379, 474, 3)

# %%
cv2.imshow('Image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1=plt.imread('OIP.jpg')
plt.imshow(img1)

# %%
img2=ski.io.imread('OIP.jpg')
ski.io.imshow(img2)

# %%
ski.io.imsave('myfile.jpg',img)
plt.imsave('myfile2.jpg',img)
cv2.imwrite('myfile.jpg',img)
# Out:
# True

# %%
img_gray=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
ski.io.imshow(img_gray)

# %%
_, img_binary=cv2.threshold(img_gray,50,255,cv2.THRESH_BINARY)
ski.io.imshow(img_binary)
